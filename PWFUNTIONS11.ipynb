# %% [raw]
# 1. Difference between a Function and a Method in Python
# A function in Python is a block of reusable code that performs a specific task.
# It can exist independently of any class or object.
# On the other hand, a method is also a function but it is associated with an object or class.
# Methods are defined inside classes and can access or modify the data of the object on which they are called.
# In short, functions are general-purpose code blocks, while methods are functions tied to class instances.
#
# 2. Concept of Function Arguments and Parameters
# Parameters are variables listed in the function definition.
# They act as placeholders for values that will be provided when the function is called.
# Arguments are the actual values or data passed to those parameters when calling the function.
# When a function executes, arguments replace the parameters, allowing the function to perform operations using real data.
#
# 3. Different Ways to Define and Call a Function
# Functions in Python can be defined in two primary ways:
# (a) Using the 'def' keyword to create a standard function.
# (b) Using the 'lambda' keyword to define an anonymous one-line function.
# Once defined, functions can be called by their name followed by parentheses containing arguments.
# Functions can also be called recursively, meaning a function can call itself to solve smaller subproblems.
#
# 4. Purpose of the 'return' Statement
# The 'return' statement in Python is used to send a value or result back to the place where the function was called.
# It ends the function’s execution immediately.
# If no return statement is provided, the function automatically returns 'None'.
# The main purpose of 'return' is to pass data from the function to the main program or another function for further use.
#
# 5. Iterators in Python and Difference from Iterables
# An iterable is any Python object capable of returning its members one at a time, such as lists, tuples, or strings.
# It implements the '__iter__()' method that returns an iterator.
# An iterator, on the other hand, is an object that keeps track of its current position and produces elements one by one using the 'next()' function.
# The difference is that iterables can be looped over multiple times, while iterators are consumed as you iterate through them.
#
# 6. Concept of Generators and How They Are Defined
# Generators are special types of iterators that generate values on the fly instead of storing them in memory.
# They are defined like normal functions but use the 'yield' keyword instead of 'return'.
# When a generator function is called, it doesn’t execute immediately. Instead, it returns a generator object.
# The code inside the generator runs each time 'next()' is called, resuming from the last 'yield' point.
#
# 7. Advantages of Generators over Regular Functions
# 1. Generators save memory because they don’t store all values in memory at once; they generate data as needed.
# 2. They improve performance when handling large datasets or infinite sequences.
# 3. They preserve the function’s state between calls using 'yield', making them efficient for iterative data processing.
# 4. They are simpler and cleaner to write compared to using iterator classes manually.
#
# 8. Lambda Function and When It Is Used
# A lambda function is a small, anonymous function defined without a name using the 'lambda' keyword.
# It can take multiple arguments but can only contain a single expression.
# Lambda functions are typically used for short, simple operations that are used temporarily.
# They are often passed as arguments to functions like map(), filter(), and sorted().
#
# 9. Purpose and Usage of map() Function
# The 'map()' function in Python is used to apply a specific operation to each element of an iterable.
# It takes two arguments: a function and an iterable.
# It returns an iterator that produces the results one by one instead of creating a list directly.
# The main purpose of 'map()' is to perform transformations or calculations on a sequence of data efficiently.
#
# 10. Difference Between map(), reduce(), and filter() Functions
# map(): Used to apply a function to every element in an iterable and return a new iterator containing the modified values.
# filter(): Used to select elements from an iterable that satisfy a specific condition or rule, returning only the matching elements.
# reduce(): Used to apply a function cumulatively to elements of an iterable, reducing the entire sequence to a single result (like sum or product).
# Together, these functions support functional programming in Python, allowing concise and readable data transformations.
#
# 11. Internal Mechanism of reduce() on [47, 11, 42, 13

# %%
# ===============================
# PYTHON PRACTICAL QUESTIONS
# ===============================

# 1️ Function to find sum of all even numbers in a list
def sum_even(numbers):
    total = 0
    for n in numbers:
        if n % 2 == 0:
            total += n
    return total

# 2️ Function to reverse a string
def reverse_string(text):
    return text[::-1]

# 3️ Function to return squares of all numbers in a list
def square_numbers(numbers):
    squares = []
    for n in numbers:
        squares.append(n * n)
    return squares

# 4️ Function to check if a number is prime (1 to 200)
def is_prime(num):
    if num < 2:
        return False
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            return False
    return True

# To check all primes from 1 to 200
for n in range(1, 201):
    if is_prime(n):
        print(n, end=" ")

# 5️ Iterator class for Fibonacci sequence
class Fibonacci:
    def __init__(self, limit):
        self.limit = limit
        self.a = 0
        self.b = 1
        self.count = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count < self.limit:
            result = self.a
            self.a, self.b = self.b, self.a + self.b
            self.count += 1
            return result
        else:
            raise StopIteration

# 6️ Generator function for powers of 2
def power_of_two(n):
    for i in range(n + 1):
        yield 2 ** i

# 7️ Generator to read file line by line
def read_file(filename):
    with open(filename, 'r') as f:
        for line in f:
            yield line.strip()

# 8️ Lambda function to sort list of tuples by second value
data = [(1, 40), (2, 10), (3, 20)]
sorted_data = sorted(data, key=lambda x: x[1])
print(sorted_data)

# 9️ Program using map() to convert Celsius to Fahrenheit
celsius = [0, 20, 37, 100]
fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))
print(fahrenheit)

#  Program using filter() to remove vowels from a string
def remove_vowels(text):
    return ''.join(filter(lambda ch: ch.lower() not in 'aeiou', text))

print(remove_vowels("Hello World"))

# 1️1️ Book shop accounting using lambda and map
orders = [
    [34587, "Learning Python", 4, 40.95],
    [98762, "Programming Python", 5, 56.80],
    [77226, "Head First Python", 3, 32.95],
    [88112, "Einführung in Python3", 3, 24.99]
]

# If total < 100 → add 10 extra
bill = list(map(lambda x: (x[0], x[2] * x[3] if x[2] * x[3] >= 100 else x[2] * x[3] + 10), orders))
print(bill)
